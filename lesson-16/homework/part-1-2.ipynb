# %% [markdown]
# Reading the files

# %%
import pandas as pd
import sqlite3

with sqlite3.connect('chinook.db') as connection:
    df_customer = pd.read_sql(
        "SELECT * FROM customers",
        con=connection  # Changed 'conn' to 'connection'
    )
df_customer.head(10)
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %%
df_json = pd.read_json("iris.json")
print(df_json.shape)
print(df_json.columns)
# Out:
# (150, 5)
# Index(['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth', 'species'], dtype='object')

# %%
df_titanic = pd.read_excel("titanic.xlsx")
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import random
df_movie = pd.read_csv("movie.csv")
rows = df_movie.sample(n=10)
print(rows)
# Out:
#                 color       director_name  num_critic_for_reviews  duration  \
# 4448            Color     Martin Scorsese                   129.0     122.0
# 2504            Color      Vadim Perelman                   158.0     126.0
# 361             Color      John McTiernan                   148.0     128.0
# 431             Color  Sylvester Stallone                   424.0     113.0
# 1755            Color         Scott Hicks                   171.0     104.0
# 872             Color       Shekhar Kapur                   202.0     114.0
# 4845            Color        Jason Miller                     5.0      77.0
# 860             Color     Stephen Hopkins                    62.0     110.0
# 4757            Color   Rachel Goldenberg                     5.0      93.0
# 2118  Black and White           Katt Shea                    85.0     104.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# ...

# %% [markdown]
# Part-2
# Exploring DataFrames

# %%
df_json.columns = df_json.columns.str.lower()
df_json.columns
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'species'], dtype='object')

# %%
print(df_json['sepallength'])
print(df_json['sepalwidth'])
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepallength, Length: 150, dtype: float64
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepalwidth, Length: 150, dtype: float64

# %%
filter_rows = df_titanic[df_titanic['Age'] > 30]
print(filter_rows)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from collections import Counter

value_counts = Counter(df_titanic['Sex'])
value_counts
# Out:
# Counter({'male': 577, 'female': 314})

# %%
filtered_rows = df_movie[df_movie['duration']>120]
filtered_rows
# Out:
#                 color        director_name  num_critic_for_reviews  duration  \
# 0               Color        James Cameron                   723.0     178.0
# 1               Color       Gore Verbinski                   302.0     169.0
# 2               Color           Sam Mendes                   602.0     148.0
# 3               Color    Christopher Nolan                   813.0     164.0
# 5               Color       Andrew Stanton                   462.0     132.0
# ...               ...                  ...                     ...       ...
# 4674            Color           Kay Pollak                    34.0     133.0
# 4695  Black and White        D.W. Griffith                    69.0     123.0
# 4767  Black and White           King Vidor                    48.0     151.0
# 4792  Black and White  Carl Theodor Dreyer                    54.0     126.0
# 4893              NaN      Brandon Landers                     NaN     143.0
#
# ...

# %%
sorted_rows = df_movie['director_facebook_likes'].sort_values(ascending=False)
sorted_rows
# Out:
# 3603    23000.0
# 66      22000.0
# 1222    22000.0
# 1057    22000.0
# 96      22000.0
#          ...
# 4683        NaN
# 4688        NaN
# 4704        NaN
# 4752        NaN
# 4912        NaN
# Name: director_facebook_likes, Length: 4916, dtype: float64
